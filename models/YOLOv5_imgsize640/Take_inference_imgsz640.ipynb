# %%
#clone YOLOv5 
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14260, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 14260 (delta 35), reused 56 (delta 30), pack-reused 14194
# Receiving objects: 100% (14260/14260), 13.36 MiB | 1.66 MiB/s, done.
# Resolving deltas: 100% (9845/9845), done.
# /content/yolov5
#      |████████████████████████████████| 1.6 MB 15.0 MB/s
#      |████████████████████████████████| 145 kB 14.3 MB/s
#      |████████████████████████████████| 54 kB 3.5 MB/s
#      |████████████████████████████████| 178 kB 31.7 MB/s
#      |████████████████████████████████| 1.1 MB 67.2 MB/s
#      |████████████████████████████████| 67 kB 6.0 MB/s
#      |████████████████████████████████| 138 kB 72.8 MB/s
#      |████████████████████████████████| 62 kB 1.7 MB/s
# ...
# Setup complete. Using torch 1.12.1+cu113 (Tesla T4)

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="wM8oWAPG8TZirTrzo38g")
project = rf.workspace("sayeh-faraz-dzv2y").project("waste-recycling")
dataset = project.version(4).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to waste-recycling-4 in yolov5pytorch:: 100%|██████████| 22752/22752 [00:09<00:00, 2482.47it/s]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# set up environment
os.environ["DATASET_DIRECTORY"] = "/content/yolov5/waste-recycling-4"

# %%
##The below snippet redirects output(stdout) to a file called Output.txt.

import sys
temp = sys.stdout
sys.stdout = f =  open('/content/yolov5/yolov5s.txt', 'w')
# !python detect.py --weights /content/gdrive/MyDrive/Weights/best_v5s640.pt --img 640 --conf 0.1 --source /content/yolov5/waste-recycling-4/test/images
sys.stdout = temp
# f.close()

# %%
# import numpy as np
# from glob import glob

# with torch.autograd.profiler.profile(use_cuda=False) as prof:
#    !python detect.py --weights /content/yolov5/best.pt --img 416 --conf 0.1 --source /content/yolov5/ax.jpg
# print(prof)

# %%
## Half precision
# import torch
import sys
temp = sys.stdout
sys.stdout = f =  open('/content/yolov5/yolov5l_half.txt', 'w')

# torch.cuda.current_device()
# !python detect.py --weights /content/gdrive/MyDrive/Weights/best_v5L640.pt --img 640 --conf 0.1 --source /content/yolov5/waste-recycling-4/test/images --device 0 --half 
sys.stdout = temp

# %%
## Time of running by CPU. We need to change run time type to None.
import sys
temp = sys.stdout
sys.stdout = f =  open('/content/yolov5/output_CPU.txt', 'w')

# torch.cuda.current_device()
# !python detect.py --weights /content/yolov5/best.pt --img 416 --conf 0.1 --source /content/yolov5/waste-separation-1/test/images  
sys.stdout = temp
